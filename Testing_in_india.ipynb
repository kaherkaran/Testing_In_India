# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline
import plotly
import plotly.express as px
import plotly.graph_objects as go
plt.rcParams['figure.figsize'] = 10,12
import cufflinks as cf 
import plotly.offline as pyo
from plotly.offline import init_notebook_mode,iplot
import folium

# %%
pyo.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Testing table
test = pd.read_csv('StatewiseTestingDetails.csv')

# %%
test.head()
# Out:
#          Date                        State  TotalSamples  Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0    1210.0      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0       NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0       NaN      33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0       NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0       NaN      33.0

# %%
test.columns
# Out:
# Index(['Date', 'State', 'TotalSamples', 'Negative', 'Positive'], dtype='object')

# %%
#Total Tests
total_tests=test['TotalSamples'].sum()
print('The total number of test till now in India is',total_tests)
# Out:
# The total number of test till now in India is 62431678.0

# %%
test.groupby('State')['TotalSamples'].sum().sort_values(ascending=False).to_frame().style.background_gradient(cmap ='Reds')
# Out:
# <style  type="text/css" >
#     #T_5e5941ba_a026_11ea_967a_84349788a2adrow0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow1_col0 {
#             background-color:  #75030f;
#             color:  #f1f1f1;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow2_col0 {
#             background-color:  #bd151a;
#             color:  #f1f1f1;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow3_col0 {
#             background-color:  #d72322;
#             color:  #f1f1f1;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow4_col0 {
#             background-color:  #f44d38;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow5_col0 {
#             background-color:  #fb7050;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow6_col0 {
#             background-color:  #fb7252;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow7_col0 {
#             background-color:  #fc8767;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow8_col0 {
#             background-color:  #fca285;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow9_col0 {
#             background-color:  #fcaf93;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow10_col0 {
#             background-color:  #fcbea5;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow11_col0 {
#             background-color:  #fcc1a8;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow12_col0 {
#             background-color:  #fcc1a8;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow13_col0 {
#             background-color:  #fdcab5;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow14_col0 {
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow15_col0 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow16_col0 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow17_col0 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow18_col0 {
#             background-color:  #fee6da;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow19_col0 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow20_col0 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow21_col0 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow22_col0 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow23_col0 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow24_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow25_col0 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow26_col0 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow27_col0 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow28_col0 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow29_col0 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow30_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow31_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow32_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow33_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_5e5941ba_a026_11ea_967a_84349788a2adrow34_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_5e5941ba_a026_11ea_967a_84349788a2ad" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >TotalSamples</th>    </tr>    <tr>        <th class="index_name level0" >State</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5e5941ba_a026_11ea_967a_84349788a2adlevel0_row0" class="row_heading level0 row0" >Tamil Nadu</th>
#                         <td id="T_5e5941ba_a026_11ea_967a_84349788a2adrow0_col0" class="data row0 col0" >8.02697e+06</td>
#             </tr>
#             <tr>
#                         <th id="T_5e5941ba_a026_11ea_967a_84349788a2adlevel0_row1" class="row_heading level0 row1" >Maharashtra</th>
#                         <td id="T_5e5941ba_a026_11ea_967a_84349788a2adrow1_col0" class="data row1 col0" >7.78941e+06</td>
#             </tr>
#             <tr>
#                         <th id="T_5e5941ba_a026_11ea_967a_84349788a2adlevel0_row2" class="row_heading level0 row2" >Rajasthan</th>
#                         <td id="T_5e5941ba_a026_11ea_967a_84349788a2adrow2_col0" class="data row2 col0" >6.37419e+06</td>
#             </tr>
#             <tr>
#                         <th id="T_5e5941ba_a026_11ea_967a_84349788a2adlevel0_row3" class="row_heading level0 row3" >Andhra Pradesh</th>
#                         <td id="T_5e5941ba_a026_11ea_967a_84349788a2adrow3_col0" class="data row3 col0" >5.67933e+06</td>
#             </tr>
#             <tr>
#                         <th id="T_5e5941ba_a026_11ea_967a_84349788a2adlevel0_row4" class="row_heading level0 row4" >Uttar Pradesh</th>
#                         <td id="T_5e5941ba_a026_11ea_967a_84349788a2adrow4_col0" class="data row4 col0" >4.61528e+06</td>
#             </tr>
#             <tr>
#                         <th id="T_5e5941ba_a026_11ea_967a_84349788a2adlevel0_row5" class="row_heading level0 row5" >Gujarat</th>
#                         <td id="T_5e5941ba_a026_11ea_967a_84349788a2adrow5_col0" class="data row5 col0" >3.87737e+06</td>
#             </tr>
#             <tr>
#                         <th id="T_5e5941ba_a026_11ea_967a_84349788a2adlevel0_row6" class="row_heading level0 row6" >Karnataka</th>
#                         <td id="T_5e5941ba_a026_11ea_967a_84349788a2adrow6_col0" class="data row6 col0" >3.81852e+06</td>
#             </tr>
#             <tr>
#                         <th id="T_5e5941ba_a026_11ea_967a_84349788a2adlevel0_row7" class="row_heading level0 row7" >Delhi</th>
#                         <td id="T_5e5941ba_a026_11ea_967a_84349788a2adrow7_col0" class="data row7 col0" >3.2895e+06</td>
#             </tr>
#             <tr>
#                         <th id="T_5e5941ba_a026_11ea_967a_84349788a2adlevel0_row8" class="row_heading level0 row8" >Madhya Pradesh</th>
#                         <td id="T_5e5941ba_a026_11ea_967a_84349788a2adrow8_col0" class="data row8 col0" >2.63908e+06</td>
#             </tr>
#             <tr>
#                         <th id="T_5e5941ba_a026_11ea_967a_84349788a2adlevel0_row9" class="row_heading level0 row9" >Odisha</th>
#                         <td id="T_5e5941ba_a026_11ea_967a_84349788a2adrow9_col0" class="data row9 col0" >2.32261e+06</td>
#             </tr>
#             <tr>
#                         <th id="T_5e5941ba_a026_11ea_967a_84349788a2adlevel0_row10" cla

# %%
px.bar(test,x= 'State', y= 'TotalSamples')
# Out:
# <div>
#
#
#             <div id="b94ffdfe-2b1a-48f6-ac63-f114522c4e17" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b94ffdfe-2b1a-48f6-ac63-f114522c4e17")) {
#                     Plotly.newPlot(
#                         'b94ffdfe-2b1a-48f6-ac63-f114522c4e17',
#                         [{"alignmentgroup": "True", "hovertemplate": "State=%{x}<br>TotalSamples=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Andaman and Nicobar Islands", "Andaman and Nicobar Islands", "Andaman and Nicobar Islands", "Andaman and Nicobar Islands", "Andaman and Nicobar Islands", "Andaman and Nicobar Islands", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Andhra Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Arunachal Pradesh", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Assam", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Bihar", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chandigarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Chhattisgarh", "Ch ...

# %%
test.columns
# Out:
# Index(['Date', 'State', 'TotalSamples', 'Negative', 'Positive'], dtype='object')

# %%
#Graphical Representation of tests
total = test.groupby('Date').sum()['TotalSamples'].reset_index()
positive = test.groupby('Date').sum()['Positive'].reset_index()
negative = test.groupby('Date').sum()['Negative'].reset_index()

fig = go.Figure()
fig.add_trace(go.Scatter(x=total['Date'], y=total['TotalSamples'], mode='lines+markers', name='Total',line=dict(color='blue', width=2)))
fig.add_trace(go.Scatter(x=positive['Date'], y=positive['Positive'], mode='lines+markers', name='Positive', line=dict(color='Red', width=2)))
fig.add_trace(go.Scatter(x=negative['Date'], y=negative['Negative'], mode='lines+markers', name='Negative', line=dict(color='Green', width=2)))
fig.update_layout(title='Tests In India', xaxis_tickfont_size=12,yaxis=dict(title='Number of Cases'))
fig.show()
# Out:
# <div>
#
#
#             <div id="a4a4d6c1-d4a6-4a25-9b02-90baf4c39923" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a4a4d6c1-d4a6-4a25-9b02-90baf4c39923")) {
#                     Plotly.newPlot(
#                         'a4a4d6c1-d4a6-4a25-9b02-90baf4c39923',
#                         [{"line": {"color": "blue", "width": 2}, "mode": "lines+markers", "name": "Total", "type": "scatter", "x": ["2020-02-16", "2020-04-01", "2020-04-02", "2020-04-03", "2020-04-04", "2020-04-05", "2020-04-06", "2020-04-07", "2020-04-08", "2020-04-09", "2020-04-10", "2020-04-11", "2020-04-12", "2020-04-13", "2020-04-14", "2020-04-15", "2020-04-16", "2020-04-17", "2020-04-18", "2020-04-19", "2020-04-20", "2020-04-21", "2020-04-22", "2020-04-23", "2020-04-24", "2020-04-25", "2020-04-26", "2020-04-27", "2020-04-28", "2020-04-29", "2020-04-30", "2020-05-01", "2020-05-02", "2020-05-03", "2020-05-04", "2020-05-05", "2020-05-06", "2020-05-07", "2020-05-08", "2020-05-09", "2020-05-10", "2020-05-11", "2020-05-12", "2020-05-13", "2020-05-14", "2020-05-15", "2020-05-16", "2020-05-17", "2020-05-18", "2020-05-19", "2020-05-20", "2020-05-21", "2020-05-22", "2020-05-23", "2020-05-24", "2020-05-25", "2020-05-26"], "y": [552.0, 11245.0, 14906.0, 20130.0, 10786.0, 59455.0, 29698.0, 76933.0, 63058.0, 109609.0, 155696.0, 171571.0, 191530.0, 210051.0, 235088.0, 261132.0, 299173.0, 333455.0, 363532.0, 423547.0, 446947.0, 486257.0, 530890.0, 574814.0, 638084.0, 686738.0, 734260.0, 792342.0, 851813.0, 927629.0, 919658.0, 990300.0, 1096691.0, 1182405.0, 1253254.0, 1345856.0, 1399515.0, 1457589.0, 1568354.0, 1666311.0, 1764615.0, 1805955.0, 1907304.0, 1983371.0, 2107684.0, 2209888.0, 2119888.0, 2391050.0, 2537831.0, 2653765.0, 2724319.0, 2888603.0, 3024580.0, 3140443.0, 3275955.0, 3173978.0, 131595.0]}, {"line": {"color": "Red", "width": 2}, "mode": "lines+markers", "name": "Positive", "type": "scatter", "x": ["2020-02-16", "2020-04-01", "2020-04-02", "2020-04-03", "2020-04-04", "2020-04-05", "2020-04-06", "2020-04-07", "2020-04-08", "2020-04-09", "2020-04-10", "2020-04-11", "2020-04-12", "2020-04-13", "2020-04-14", "2020-04-15", "2020-04-16", "2020-04-17", "2020-04-18", "2020-04-19", "2020-04-20", "2020-04-21", "2020-04-22", "2020-04-23", "2020-04-24", "2020-04-25", "2020-04-26", "2020-04-27", "2020-04-28", "2020-04-29", "2020-04-30", "2020-05-01", "2020-05-02", "2020-05-03", "2020-05-04", "2020-05-05", "2020-05-06", "2020-05-07", "2020-05-08", "2020-05-09", "2020-05-10", "2020-05-11", "2020-05-12", "2020-05-13", "2020-05-14", "2020-05-15", "2020-05-16", "2020-05-17", "2020-05-18", "2020-05-19", "2020-05-20", "2020-05-21", "2020-05-22", "2020-05-23", "2020-05-24", "2020-05-25", "2020-05-26"], "y": [7.0, 302.0, 510.0, 898.0, 306.0, 1493.0, 1196.0, 2974.0, 2473.0, 4681.0, 6490.0, 7830.0, 8380.0, 9389.0, 10408.0, 11409.0, 12341.0, 13437.0, 14481.0, 16723.0, 17147.0, 18533.0, 19912.0, 20749.0, 22995.0, 24387.0, 26643.0, 27787.0, 30513.0, 32403.0, 29634.0, 30619.0, 37706.0, 40611.0, 43677.0, 47219.0, 50487.0, 53804.0, 57260.0, 60403.0, 63879.0, 69313.0, 71738.0, 74837.0, 78722.0, 82498.0, 86615.0, 91345.0, 96359.0, 101710.0, 106485.0, 112429.0, 118209.0, 124663.0, 130972.0, 132276.0, 1517.0]}, {"line": {"color": "Green", "width": 2}, "mode": "lines+markers", "name": "Negative", "type": "scatter", "x": ["2020-02-16", "2020-04-01", "2020-04-02", "2020-04-03", "2020-04-04", "2020-04-05", "2020-04-06", "2020-04-07", "2020-04-08", "2020-04-09", "2020-04-10", "2020-04-11", "2020-04-12", "2020-04-13", "2020-04-14", "2020-04-15", "2020-04-16", "2020-04-17", "2020-04-18", "2020-04-19", "2020-04-20", "2020-04-21", "2020-04-22", "2020-04-23", "2020-04-24", "2020-04-25", "2020-04-26", "2020-04-27", "2020-04-28", "2020-04-29", "2020-04-30", "2020-05-01", "2020-05-02", "2020-05-03", "2020-05-04", "2020-05-05", "2020-05-06", "2020-05-07", "2020-05-08", "2020-05-09", "2020-05-10", "2020-05-11", "2020-05-12", "2020-05-13", "2020-05-14", "2020-05-15", "2020-05-16", "2020-05-17", "2020-05-18", "2020-05-19", "2020-05-20", "2020-05-21", "2020-05-22", "2020-05-23", "2020-05-24", "2020-05-25", "2020-05-26"], "y": [299.0, 7824.0, 12622.0, 17242.0, 8586.0, 53149.0, 25462.0, 65229.0, 52602.0, 91635.0, 134546.0, 146496.0, 153599.0, 167714.0, 199078.0, 222060.0, 25 ...
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}],

# %%
#For Mapping

# %%
india_cord = pd.read_csv("Indian Coordinates.csv")

# %%
india_cord.head()
# Out:
#      Name of State / UT   Latitude  Longitude  Unnamed: 3
# 0  Andaman And Nicobar   11.667026  92.735983         NaN
# 1        Andhra Pradesh  14.750429  78.570026         NaN
# 2    Arunachal Pradesh   27.100399  93.616601         NaN
# 3                Assam   26.749981  94.216667         NaN
# 4                Bihar   25.785414  87.479973         NaN

# %%
india_cord.drop(['Unnamed: 3'],axis=1,inplace = True)

# %%
india_cord.head()
# Out:
#      Name of State / UT   Latitude  Longitude
# 0  Andaman And Nicobar   11.667026  92.735983
# 1        Andhra Pradesh  14.750429  78.570026
# 2    Arunachal Pradesh   27.100399  93.616601
# 3                Assam   26.749981  94.216667
# 4                Bihar   25.785414  87.479973

# %%
india_cord.rename(columns={'Name of State / UT' : 'State'},inplace=True)

# %%
india_cord.head()
# Out:
#                   State   Latitude  Longitude
# 0  Andaman And Nicobar   11.667026  92.735983
# 1        Andhra Pradesh  14.750429  78.570026
# 2    Arunachal Pradesh   27.100399  93.616601
# 3                Assam   26.749981  94.216667
# 4                Bihar   25.785414  87.479973

# %%
df_full = pd.merge(india_cord,test,on='State')

# %%
df_full
# Out:
#               State   Latitude  Longitude        Date  TotalSamples  Negative  \
# 0    Andhra Pradesh  14.750429  78.570026  2020-04-02        1800.0    1175.0
# 1    Andhra Pradesh  14.750429  78.570026  2020-04-10        6374.0    6009.0
# 2    Andhra Pradesh  14.750429  78.570026  2020-04-11        6958.0    6577.0
# 3    Andhra Pradesh  14.750429  78.570026  2020-04-12        6958.0    6553.0
# 4    Andhra Pradesh  14.750429  78.570026  2020-04-13        8755.0    8323.0
# ..              ...        ...        ...         ...           ...       ...
# 538     Uttarakhand  30.320409  78.050006  2020-05-21       16528.0   13808.0
# 539     Uttarakhand  30.320409  78.050006  2020-05-22       18008.0   14960.0
# 540     Uttarakhand  30.320409  78.050006  2020-05-23       19248.0   15757.0
# 541     Uttarakhand  30.320409  78.050006  2020-05-24       20969.0   16640.0
# 542     Uttarakhand  30.320409  78.050006  2020-05-25       22117.0   17315.0
#
#      Positive
# 0       132.0
# 1       365.0
# 2       381.0
# 3       405.0
# 4       432.0
# ..        ...
# 538     132.0
# 539     151.0
# 540     173.0
# 541     293.0
# 542     332.0
#
# [543 rows x 7 columns]

# %%
map = folium.Map(location=[20, 70], zoom_start=4,tiles='Stamenterrain')

for lat, lon, value, name in zip(df_full['Latitude'], df_full['Longitude'], df_full['TotalSamples'], df_full['State']):
    folium.CircleMarker([lat, lon], radius=value*0.000005, popup = ('<strong>State</strong>: ' + str(name).capitalize() + '<br>''<strong>Total Tests</strong>: ' + str(value) + '<br>'),color='red',fill_color='red',fill_opacity=0.1 ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Beds Per State
beds = pd.read_csv('HospitalBedsIndia.csv')

# %%
beds.head()
# Out:
#    Sno                   State/UT NumPrimaryHealthCenters_HMIS  \
# 0    1  Andaman & Nicobar Islands                           27
# 1    2             Andhra Pradesh                         1417
# 2    3          Arunachal Pradesh                          122
# 3    4                      Assam                         1007
# 4    5                      Bihar                         2007
#
#    NumCommunityHealthCenters_HMIS  NumSubDistrictHospitals_HMIS  \
# 0                               4                           NaN
# 1                             198                          31.0
# 2                              62                           NaN
# 3                             166                          14.0
# 4                              63                          33.0
#
#    NumDistrictHospitals_HMIS  TotalPublicHealthFacilities_HMIS  \
# 0                          3                                34
# 1                         20                              1666
# 2                         15                               199
# 3                         33                              1220
# 4                         43                              2146
#
#    NumPublicBeds_HMIS  NumRuralHospitals_NHP18  NumRuralBeds_NHP18  \
# 0                1246                       27                 575
# 1               60799                      193                6480
# 2                2320                      208                2136
# 3               19115                     1176               10944
# 4               17796                      930                6083
#
#    NumUrbanHospitals_NHP18  NumUrbanBeds_NHP18
# 0                        3                 500
# 1                       65               16658
# 2                       10                 268
# 3                       50                6198
# 4                      103                5936

# %%
beds.groupby('State/UT')['NumPublicBeds_HMIS'].sum().sort_values(ascending=False).to_frame().style.background_gradient(cmap ='Blues')
# Out:
# <style  type="text/css" >
#     #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow1_col0 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow2_col0 {
#             background-color:  #e5eff9;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow3_col0 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow4_col0 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow5_col0 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow6_col0 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow7_col0 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow8_col0 {
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow9_col0 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow10_col0 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow11_col0 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow12_col0 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow13_col0 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow14_col0 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow15_col0 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow16_col0 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow17_col0 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow18_col0 {
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow19_col0 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow20_col0 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow21_col0 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow22_col0 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow23_col0 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow24_col0 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow25_col0 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow26_col0 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow27_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow28_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow29_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow30_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow31_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow32_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow33_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow34_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow35_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_e9bf4a5c_a027_11ea_af68_84349788a2adrow36_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_e9bf4a5c_a027_11ea_af68_84349788a2ad" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >NumPublicBeds_HMIS</th>    </tr>    <tr>        <th class="index_name level0" >State/UT</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e9bf4a5c_a027_11ea_af68_84349788a2adlevel0_row0" class="row_heading level0 row0" >All India</th>
#                         <td id="T_e9bf4a5c_a027_11ea_af68_84349788a2adrow0_col0" class="data row0 col0" >739024</td>
#             </tr>
#             <tr>
#                         <th id="T_e9bf4a5c_a027_11ea_af68_84349788a2adlevel0_row1" class="row_heading level0 row1" >Tamil Nadu</th>
#                         <td id="T_e9bf4a5c_a027_11ea_af68_84349788a2adrow1_col0" class="data row1 col0" >72616</td>
#             </tr>
#             <tr>
#                         <th id="T_e9bf4a5c_a027_11ea_af68_84349788a2adlevel0_row2" class="row_heading level0 row2" >Maharashtra</th>
#                         <td id="T_e9bf4a5c_a027_11ea_af68_84349788a2adrow2_col0" class="data row2 col0" >68998</td>
#             </tr>
#             <tr>
#                         <th id="T_e9bf4a5c_a027_11ea_af68_84349788a2adlevel0_row3" class="row_heading level0 row3" >Andhra Pradesh</th>
#                         <td id="T_e9bf4a5c_a027_11ea_af68_84349788a2adrow3_col0" class="data row3 col0" >60799</td>
#             </tr>
#             <tr>
#                         <th id="T_e9bf4a5c_a027_11ea_af68_84349788a2adlevel0_row4" class="row_heading level0 row4" >Uttar Pradesh</th>
#                         <td id="T_e9bf4a5c_a027_11ea_af68_84349788a2adrow4_col0" class="data row4 col0" >58310</td>
#             </tr>
#             <tr>
#                         <th id="T_e9bf4a5c_a027_11ea_af68_84349788a2adlevel0_row5" class="row_heading level0 row5" >Karnataka</th>
#                         <td id="T_e9bf4a5c_a027_11ea_af68_84349788a2adrow5_col0" class="data row5 col0" >56333</td>
#             </tr>
#             <tr>
#                         <th id="T_e9bf4a5c_a027_11ea_af68_84349788a2adlevel0_row6" class="row_heading level0 row6" >Rajasthan</th>
#                         <td id="T_e9bf4a5c_a027_11ea_af68_84349788a2adrow6_col0" class="data row6 col0" >51844</td>
#             </tr>
#             <tr>
#                         <th id="T_e9bf4a5c_a027_11ea_af68_84349788a2adlevel0_row7" class="row_heading level0 row7" >West Bengal</th>
#                         <td id="T_e9bf4a5c_a027_11ea_af68_84349788a2adrow7_col0" class="data row7 col0" >51163</td>
#             </tr>
#             <tr>
#                         <th id="T_e9bf4a5c_a027_11ea_af68_84349788a2adlevel0_row8" class="row_heading level0 row8" >Gujarat</th>
#                         <td id="T_e9bf4a5c_a027_11ea_af68_84349788a2adrow8_col0" class="data row8 col0" >41129</td>
#             </tr>
#             <tr>
#                         <th id="T_e9bf4a5c_a027_11ea_af68_84349788a2adlevel0_row9" class="row_heading level0 row9" >Kerala</th>

# %%
px.bar(beds,x= 'State/UT', y= 'NumPublicBeds_HMIS')
# Out:
# <div>
#
#
#             <div id="c0143537-195f-441b-ade9-ec6b19b1b18c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c0143537-195f-441b-ade9-ec6b19b1b18c")) {
#                     Plotly.newPlot(
#                         'c0143537-195f-441b-ade9-ec6b19b1b18c',
#                         [{"alignmentgroup": "True", "hovertemplate": "State/UT=%{x}<br>NumPublicBeds_HMIS=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Andaman & Nicobar Islands", "Andhra Pradesh", "Arunachal Pradesh", "Assam", "Bihar", "Chandigarh", "Chhattisgarh", "Dadra & Nagar Haveli", "Daman & Diu", "Delhi", "Goa", "Gujarat", "Haryana", "Himachal Pradesh", "Jammu & Kashmir", "Jharkhand", "Karnataka", "Kerala", "Lakshadweep", "Madhya Pradesh", "Maharashtra", "Manipur", "Meghalaya", "Mizoram", "Nagaland", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Sikkim", "Tamil Nadu", "Telangana", "Tripura", "Uttar Pradesh", "Uttarakhand", "West Bengal", "All India"], "xaxis": "x", "y": [1246, 60799, 2320, 19115, 17796, 3756, 14354, 568, 298, 20572, 2666, 41129, 13841, 8706, 11342, 7404, 56333, 39511, 250, 38140, 68998, 2562, 4585, 2312, 1944, 16497, 4462, 13527, 51844, 1145, 72616, 17358, 4895, 58310, 6660, 51163, 739024], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
beds.iplot(kind="scatter", x= 'State/UT', y= 'NumPublicBeds_HMIS',mode='markers+lines',title='Beds',xTitle='Name of State / UT',yTitle='Total Beds',colors='red',size=20)
# Out:
# <div>
#
#
#             <div id="81ab1308-b9c2-47fc-a557-28700b3db5eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("81ab1308-b9c2-47fc-a557-28700b3db5eb")) {
#                     Plotly.newPlot(
#                         '81ab1308-b9c2-47fc-a557-28700b3db5eb',
#                         [{"line": {"color": "rgba(219, 64, 82, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 20, "symbol": "circle"}, "mode": "markers+lines", "name": "NumPublicBeds_HMIS", "text": "", "type": "scatter", "x": ["Andaman & Nicobar Islands", "Andhra Pradesh", "Arunachal Pradesh", "Assam", "Bihar", "Chandigarh", "Chhattisgarh", "Dadra & Nagar Haveli", "Daman & Diu", "Delhi", "Goa", "Gujarat", "Haryana", "Himachal Pradesh", "Jammu & Kashmir", "Jharkhand", "Karnataka", "Kerala", "Lakshadweep", "Madhya Pradesh", "Maharashtra", "Manipur", "Meghalaya", "Mizoram", "Nagaland", "Odisha", "Puducherry", "Punjab", "Rajasthan", "Sikkim", "Tamil Nadu", "Telangana", "Tripura", "Uttar Pradesh", "Uttarakhand", "West Bengal", "All India"], "y": [1246, 60799, 2320, 19115, 17796, 3756, 14354, 568, 298, 20572, 2666, 41129, 13841, 8706, 11342, 7404, 56333, 39511, 250, 38140, 68998, 2562, 4585, 2312, 1944, 16497, 4462, 13527, 51844, 1145, 72616, 17358, 4895, 58310, 6660, 51163, 739024]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {" ...

# %%
icmr = pd.read_csv('ICMRTestingLabs.csv')

# %%
icmr.head()
# Out:
#                                                  lab  \
# 0  ICMR-Regional Medical Research Centre, Port Blair
# 1  Tomo Riba Institute of Health & Medical Scienc...
# 2  Sri Venkateswara Institute of Medical Sciences...
# 3                Rangaraya Medical College, Kakinada
# 4               Sidhartha Medical College, Vijaywada
#
#                                              address  pincode        city  \
# 0  ICMR-Regional Medical Research Centre, Post Ba...   744103  Port Blair
# 1  National Highway 52A, Old Assembly Complex, Na...   791110  Naharlagun
# 2  Sri Venkateswara Institute of Medical Sciences...   517507    Tirupati
# 3  Rangaraya Medical College, Kakinada Pithampura...   533001    Kakinada
# 4  Siddhartha Medical College, Vijayawada NH 16 S...   520008  Vijayawada
#
#                          state                   type
# 0  Andaman and Nicobar Islands  Government Laboratory
# 1            Arunachal Pradesh        Collection Site
# 2               Andhra Pradesh  Government Laboratory
# 3               Andhra Pradesh  Government Laboratory
# 4               Andhra Pradesh  Government Laboratory

# %%
icmr.columns
# Out:
# Index(['lab', 'address', 'pincode', 'city', 'state', 'type'], dtype='object')

# %%
total_labs=icmr['lab'].value_counts()
print('The total number Labs now in India is',total_labs)
# Out:
# The total number Labs now in India is K.A.P. Viswanatham Government Medical College, Trichy                                                  2
# Silchar Medical College, Silchar                                                                       1
# Government Medical College, Patiala                                                                    1
# City x-Ray & Scan Clinic Pvt. Ltd., New Delhi                                                          1
# Cancyte Technologies Private Limited, Bengaluru                                                        1
#                                                                                                       ..
# Gauhati Medical College, Guwahati                                                                      1
# Ram Manohar Lohia Hospital, New Delhi                                                                  1
# North Eastern Indira Gandhi Regional Institute of Health and Medical Sciences (NEIGRIHMS), Shillong    1
# Dr Lal PathLabs, National Reference laboratory                                                         1
# Laboratory Services, Peerless Hospitex Hospital & Research Center Limited, Kolkata                     1
# Name: lab, Length: 266, dtype: int64
